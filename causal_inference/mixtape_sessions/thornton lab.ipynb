# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
df = pd.read_stata("https://raw.github.com/scunning1975/mixtape/master/thornton_hiv.dta", )

# %%
df.head()
# Out:
#    site  rumphi  balaka  villnum  m1out  m2out  survey2004  got  zone  \
# 0   2.0     0.0     1.0      1.0    NaN    NaN         1.0  1.0  12.0
# 1   2.0     0.0     1.0      1.0    NaN    2.0         1.0  NaN  12.0
# 2   2.0     0.0     1.0      1.0    NaN    NaN         1.0  1.0  12.0
# 3   2.0     0.0     1.0      1.0    NaN    2.0         0.0  NaN  12.0
# 4   2.0     0.0     1.0      1.0    NaN    2.0         1.0  1.0  12.0
#
#     distvct  ...  under_havesex_fo_hiv  over_havesex_fo_hiv  hiv_havesex_fo  \
# 0  2.718921  ...                   0.0                  0.0             0.0
# 1  2.835039  ...                   NaN                  NaN             NaN
# 2  2.485713  ...                   0.0                  0.0             0.0
# 3  2.835039  ...                   NaN                  NaN             NaN
# 4  1.837131  ...                   0.0                  0.0             0.0
#
#    havesex_fo_hiv  any_havesex_fo_male  tinc_havesex_fo_male  \
# ...

# %%
# difference between the two means
df.groupby('any').agg({'got': 'mean'})
# Out:
#           got
# any
# 0.0  0.338684
# 1.0  0.789236

# %%
df = df[(~df['got'].isna()) & (~df['any'].isna())]

# %%
# ---- 1.b. Calculate using OLS
Y = df['got']
X = df['any']
# X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                    got   R-squared (uncentered):                   0.704
# Model:                            OLS   Adj. R-squared (uncentered):              0.704
# Method:                 Least Squares   F-statistic:                              6741.
# Date:                Sat, 04 Feb 2023   Prob (F-statistic):                        0.00
# Time:                        14:37:36   Log-Likelihood:                         -1770.3
# No. Observations:                2834   AIC:                                      3543.
# Df Residuals:                    2833   BIC:                                      3549.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
